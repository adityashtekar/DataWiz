# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_df = pd.read_csv('train.csv')

train_df['Start Date'] = pd.to_datetime(train_df['Start Date'],errors='coerce')
train_df['End Date'] = pd.to_datetime(train_df['End Date'],errors='coerce')
# train_df['End Date'].fillna(value=train_df['End Date'].max(),inplace=True)
# train_df['Start Month'] = train_df['Start Date'].dt.month
# train_df['Start Day'] = train_df['Start Date'].dt.day
# train_df['Start Year'] = train_df['Start Date'].dt.year
# train_df['End Month'] = train_df['End Date'].dt.month
# train_df['End Day'] = train_df['End Date'].dt.day
# train_df['End Year'] = train_df['End Date'].dt.year
train_df['Duration']= train_df['End Date'] - train_df['Start Date']
train_df['Duration'] = train_df['Duration'].dt.days
# check_df = train_df.loc[train_df['Start Date']>train_df['End Date'],:]
# train_df.loc[train_df.Duration<0,'Duration'] = None

print(train_df.head())
print(train_df.describe())
print(train_df.info())
# Out:
#    ID Start Date   End Date                    Category     Currency   Goal  \
# 0   1 2014-03-06 2014-04-08             Arts & Creative          USD  10000
# 1   2 2014-03-11 2014-04-20             Arts & Creative          USD  20000
# 2   3 2014-04-02 2014-04-23                Film & Video          USD   2700
# 3   4 2017-09-23        NaT  Health, Illness or Medical  U.S. Dollar  36900
# 4   5 2014-01-13 2014-01-30                       Music          USD   1200
#
#    Status  Duration
# 0  Failed      33.0
# 1  Failed      40.0
# 2  Failed      21.0
# 3  Failed       NaN
# 4  Failed      17.0
#                  ID          Goal     Duration
# count  12120.000000  1.212000e+04  9471.000000
# mean    6060.500000  1.834589e+05    33.789674
# std     3498.886966  1.284568e+07    41.579027
# min        1.000000  5.000000e+00  -111.000000
# 25%     3030.750000  1.800000e+03    30.000000
# 50%     6060.500000  5.000000e+03    30.000000
# 75%     9090.250000  1.200000e+04    33.000000
# max    12120.000000  1.000000e+09  2373.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12120 entries, 0 to 12119
# Data columns (total 8 columns):
# ID            12120 non-null int64
# Start Date    12118 non-null datetime64[ns]
# End Date      9473 non-null datetime64[ns]
# Category      12120 non-null object
# Currency      12120 non-null object
# Goal          12120 non-null int64
# Status        12120 non-null object
# Duration      9471 non-null float64
# dtypes: datetime64[ns](2), float64(1), int64(2), object(3)
# memory usage: 757.6+ KB
# None

# %%
test_df = pd.read_csv('test.csv')
test_df['Start Date'] = pd.to_datetime(test_df['Start Date'],errors='coerce')
test_df['End Date'] = pd.to_datetime(test_df['End Date'],errors='coerce')

test_df['Duration']= test_df['End Date'] - test_df['Start Date']
test_df['Duration'] = test_df['Duration'].dt.days

test_df.loc[test_df['Duration']<0,'Duration'] = None
print(test_df.head())
print(test_df.describe())
print(test_df.info())
# Out:
#       ID Start Date   End Date         Category         Currency   Goal  \
# 0  12121 2014-04-18 2014-05-18            Games              USD  10000
# 1  12122 2014-03-05 2014-04-04  Arts & Creative              USD   7500
# 2  12123 2014-02-04 2014-03-06     Film & Video              USD    500
# 3  12124 2014-03-25 2014-04-24            Games              USD  29550
# 4  12125 2015-09-14        NaT         Politics  Canadian Dollar   2500
#
#    Duration
# 0      30.0
# 1      30.0
# 2      30.0
# 3      30.0
# 4       NaN
#                  ID          Goal     Duration
# count   8080.000000  8.080000e+03  6224.000000
# mean   16160.500000  6.532109e+05    34.450996
# std     2332.639421  5.563531e+07    39.986654
# min    12121.000000  5.000000e+00     3.000000
# 25%    14140.750000  2.000000e+03    30.000000
# 50%    16160.500000  5.000000e+03    30.000000
# 75%    18180.250000  1.200000e+04    33.000000
# max    20200.000000  5.000000e+09  1816.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8080 entries, 0 to 8079
# Data columns (total 7 columns):
# ID            8080 non-null int64
# Start Date    8078 non-null datetime64[ns]
# End Date      6261 non-null datetime64[ns]
# Category      8080 non-null object
# Currency      8080 non-null object
# Goal          8080 non-null int64
# Duration      6224 non-null float64
# dtypes: datetime64[ns](2), float64(1), int64(2), object(2)
# memory usage: 442.0+ KB
# None

# %%
print(train_df['Category'].value_counts())
# Out:
# Film & Video                  1803
# Music                         1433
# Arts & Creative               1168
# Publishing                    1047
# Games                          812
# Design                         727
# Fashion                        549
# Food                           529
# Technology                     502
# Theater                        311
# Photography                    292
# Community & Volunteer          181
# Business                       181
# Sports & Competitions          178
# Animals & Humane               177
# Legal                          176
# Family & Kids                  175
# Travel                         170
# Education & Schools            168
# Faith & Religion               163
# Veterans & Heroes              156
# Accidents & Disasters          151
# Non-profits & Charity          151
# Politics                       149
# Dance                          148
# Celebrations and Weddings      140
# Health, Illness or Medical     133
# Memorials & Funerals           121
# Alumni & Clubs                  99
# Crafts                          97
# Journalism                      33
# Name: Category, dtype: int64

# %%
print(train_df['Currency'].value_counts())
# Out:
# USD                   7332
# U.S. Dollar           2080
# GBP                   1187
# CAD                    442
# Canadian Dollar        398
# AUD                    248
# Pound Sterling         169
# Euro                   112
# NZD                     51
# Australian Dollar       44
# EUR                     23
# New Zealand Dollar       6
# Hong Kong Dollar         5
# Philippine Peso          5
# Thai Baht                4
# Israeli New Sheqel       3
# Japanese Yen             2
# Swiss Franc              2
# Swedish Krona            2
# Russian Ruble            1
# Danish Krone             1
# Norwegian Krone          1
# Polish Zlotych           1
# Singapore Dollar         1
# Name: Currency, dtype: int64

# %%
train_df.loc[train_df.Currency=='U.S. Dollar','Currency'] = 'USD'
train_df.loc[train_df.Currency=='Canadian Dollar','Currency'] = 'CAD'
train_df.loc[train_df.Currency=='Pound Sterling','Currency'] = 'GBP'
train_df.loc[train_df.Currency=='Australian Dollar','Currency'] = 'AUD'
train_df.loc[train_df.Currency=='Euro','Currency'] = 'EUR'
train_df.loc[train_df.Currency=='New Zealand Dollar','Currency'] = 'NZD'
print(train_df['Currency'].value_counts())
# Out:
# USD                   9412
# GBP                   1356
# CAD                    840
# AUD                    292
# EUR                    135
# NZD                     57
# Hong Kong Dollar         5
# Philippine Peso          5
# Thai Baht                4
# Israeli New Sheqel       3
# Swedish Krona            2
# Swiss Franc              2
# Japanese Yen             2
# Russian Ruble            1
# Danish Krone             1
# Norwegian Krone          1
# Polish Zlotych           1
# Singapore Dollar         1
# Name: Currency, dtype: int64

# %%
test_df['Currency'].value_counts()
# Out:
# USD                   4813
# U.S. Dollar           1420
# GBP                    793
# CAD                    326
# Canadian Dollar        273
# Pound Sterling         142
# AUD                    139
# Euro                    61
# Australian Dollar       37
# NZD                     31
# EUR                     23
# Thai Baht                4
# New Zealand Dollar       3
# Swiss Franc              3
# Russian Ruble            2
# Philippine Peso          2
# Singapore Dollar         2
# Israeli New Sheqel       1
# Japanese Yen             1
# Norwegian Krone          1
# Polish Zlotych           1
# Swedish Krona            1
# Mexican Peso             1
# Name: Currency, dtype: int64

# %%
test_df.loc[test_df.Currency=='U.S. Dollar','Currency'] = 'USD'
test_df.loc[test_df.Currency=='Canadian Dollar','Currency'] = 'CAD'
test_df.loc[test_df.Currency=='Pound Sterling','Currency'] = 'GBP'
test_df.loc[test_df.Currency=='Australian Dollar','Currency'] = 'AUD'
test_df.loc[test_df.Currency=='Euro','Currency'] = 'EUR'
test_df.loc[test_df.Currency=='New Zealand Dollar','Currency'] = 'NZD'
test_df.loc[test_df.Currency=='Mexican Peso','Currency'] = 'Philippine Peso'
print(test_df['Currency'].value_counts())
# Out:
# USD                   6233
# GBP                    935
# CAD                    599
# AUD                    176
# EUR                     84
# NZD                     34
# Thai Baht                4
# Swiss Franc              3
# Philippine Peso          3
# Russian Ruble            2
# Singapore Dollar         2
# Polish Zlotych           1
# Norwegian Krone          1
# Israeli New Sheqel       1
# Japanese Yen             1
# Swedish Krona            1
# Name: Currency, dtype: int64

# %%
pair_df = train_df.dropna()
sns.pairplot(pair_df,hue='Status')

# %%
pair_df = test_df.dropna()
sns.pairplot(pair_df)

# %%
train_df.corr()
# Out:
#                 ID      Goal  Duration
# ID        1.000000 -0.001578 -0.009390
# Goal     -0.001578  1.000000  0.028156
# Duration -0.009390  0.028156  1.000000

# %%
train_df
# Out:
#           ID Start Date   End Date                    Category Currency  \
# 0          1 2014-03-06 2014-04-08             Arts & Creative      USD
# 1          2 2014-03-11 2014-04-20             Arts & Creative      USD
# 2          3 2014-04-02 2014-04-23                Film & Video      USD
# 3          4 2017-09-23        NaT  Health, Illness or Medical      USD
# 4          5 2014-01-13 2014-01-30                       Music      USD
# 5          6 2015-02-25        NaT           Veterans & Heroes      USD
# 6          7 2014-03-25 2014-05-04                Film & Video      USD
# 7          8 2014-02-21 2014-03-21                       Games      USD
# 8          9 2013-10-22        NaT           Veterans & Heroes      USD
# 9         10 2014-04-02 2014-04-23                Film & Video      USD
# 10        11 2013-09-29        NaT   Celebrations and Weddings      USD
# 11        12 2014-02-13 2014-03-15                        Food      GBP
# 12        13 2014-01-02 2014-02-01                      Design      USD
# 13        14 2014-05-09 2014-06-10                      Design      USD
# 14        15 2014-03-06 2014-04-20                      Design      USD
# 15        16 2013-12-25 2014-02-08                       Music      USD
# 16        17 2014-04-08 2014-05-08                Film & Video      CAD
# 17        18 2014-05-10 2014-06-11                Film & Video      GBP
# 18        19 2014-02-02 2014-03-04                Film & Video      AUD
# 19        20 2014-03-29 2014-04-28             Arts & Creative      USD
# 20        21 2014-02-01 2014-03-18                     Fashion      USD
# 21        22 2014-02-27 2014-03-29                Film & Video      USD
# 22        23 2014-04-02 2014-05-02             Arts & Creative      USD
# 23        24 2014-05-22 2014-06-21                Film & Video      USD
# 24        25 2014-03-21 2014-05-10                      Design      USD
# 25        26 2014-05-08 2014-06-07                Film & Video      USD
# 26        27 2015-10-07        NaT        Memorials & Funerals      USD
# 27        28 2014-02-01 2014-03-08                       Music      USD
# 28        29 2014-01-31 2014-04-01                        Food      CAD
# 29        30 2014-02-10 2014-04-11                  Technology      CAD
# ...      ...        ...        ...                         ...      ...
# 12090  12091 2014-04-14 2014-06-05                  Technology      GBP
# 12091  12092 2014-03-12 2014-04-20             Arts & Creative      USD
# 12092  12093 2015-11-24        NaT               Family & Kids      USD
# 12093  12094 2014-02-21 2014-03-14                       Music      USD
# 12094  12095 2018-05-01        NaT            Faith & Religion      EUR
# 12095  12096 2016-09-08        NaT                       Legal      USD
# 12096  12097 2014-01-28 2014-02-04                      Design      USD
# 12097  12098 2014-04-09 2014-05-19                       Music      USD
# 12098  12099 2014-03-24 2014-04-23                  Technology      GBP
# 12099  12100 2014-09-28        NaT       Accidents & Disasters      USD
# 12100  12101 2016-07-13        NaT                    Politics      USD
# 12101  12102 2014-03-29 2014-04-28                      Crafts      GBP
# 12102  12103 2014-04-23 2014-05-23                       Music      USD
# 12103  12104 2014-04-01 2014-05-01                       Music      USD
# 12104  12105 2014-05-23 2014-06-20                     Theater      GBP
# 12105  12106 2014-03-19 2014-04-03                  Publishing      USD
# 12106  12107 2016-05-19        NaT               Family & Kids      USD
# 12107  12108 2013-12-16 2014-01-30                Film & Video      AUD
# 12108  12109 2016-02-16        NaT             Arts & Creative      USD
# 12109  12110 2016-06-18        NaT            Animals & Humane      CAD
# 12110  12111 2014-01-10 2014-03-11                  Publishing      GBP
# 12111  12112 2016-06-21        NaT                      Travel      NZD
# 12112  12113 2014-04-01 2014-05-05                Film & Video      USD
# 12113  12114 2014-03-07 2014-04-13                       Music      AUD
# 12114  12115 2016-08-13        NaT                       Legal      USD
# 12115  12116 2014-01-22 2014-02-14                Film & Video      USD
# 12116  12117 2014-01-03 2014-02-17                 Photography      USD
# 12117  12118 2014-03-18 2014-04-12                       Music      USD
# 12118  12119 2018-07-18        NaT         Education & Schools      USD
# 12119  12120 2014-05-02 2014-06-03                Film & Video      USD
#
#          Goal   Status  Duration
# 0       10000   Failed      33.0
# 1       20000   Failed      40.0
# 2        2700   Failed      21.0
# 3       36900   Failed       NaN
# 4        1200   Failed      17.0
# 5         500   Failed       NaN
# 6        4500  Success      40.0
# 7        1700  Success      28.0
# 8        3000   Failed       NaN
# 9         700  Success      21.0
# 10        200   Failed       NaN
# 11      22000  Success      30.0
# 12      12000   Failed      30.0
# 13       8000   Failed      32.0
# 14      45000   Failed      45.0
# 15        200  Success      45.0
# 16      25000   Failed      30.0
# 17       1750   Failed      32.0
# 18      20000   Failed      30.0
# 19      20000   Failed      30.0
# 20     100000   Failed      45.0
# 21       1200  Success      30.0
# 22      10000  Success      30.0
# 23      75000   Failed      30.0
# 24      24500   Failed      50.0
# 25      10000  Success      30.0
# 26       1800  Success       NaN
# 27       3500   Failed      35.0
# 28       9000  Success      60.0
# 29     150000   Failed      60.0
# ...       ...      ...       ...
# 12090   60000   Failed      52.0
# 12091    4300  Success      39.0
# 12092    5700   Failed       NaN
# 12093    6500  Success      21.0
# 12094    1000   Failed       NaN
# 12095    6000   Failed       NaN
# 12096     100  Success       7.0
# 12097    1000  Success      40.0
# 12098   25000   Failed      30.0
# 12099    8000   Failed       NaN
# 12100    2500   Failed       NaN
# 12101    9000  Success      30.0
# 12102    7500  Success      30.0
# 12103    3000  Success      30.0
# 12104   12500   Failed      28.0
# 12105    7500   Failed      15.0
# 12106    2000   Failed       NaN
# 12107    3500   Failed      45.0
# 12108     200  Success       NaN
# 12109   20000   Failed       NaN
# 12110    6000   Failed      60.0
# 12111    2000   Failed       NaN
# 12112  350000   Failed      34.0
# 12113   15000  Success      37.0
# 12114    8000   Failed       NaN
# 12115    4500  Success      23.0
# 12116   15882   Failed      45.0
# 12117    8000  Success      25.0
# 12118    1000   Failed       NaN
# 12119    8000  Success      32.0
#
# [12120 rows x 8 columns]

# %%
train_df['Duration'].fillna(value=train_df['Duration'].mean(),inplace=True)
test_df['Duration'].fillna(value=test_df['Duration'].mean(),inplace=True)
# print(str(diff))

# %% [markdown]
# # Model

# %%
from sklearn.model_selection import train_test_split,RandomizedSearchCV
from sklearn.metrics import roc_auc_score,f1_score
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing  import LabelEncoder,RobustScaler
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb

# %%
scaler = RobustScaler()
X = train_df.drop(['ID','Start Date','End Date'],axis=1)
    

le = LabelEncoder()
for i in X.select_dtypes('object').columns:
    X[str(i)] = le.fit_transform(X[str(i)])

target = X['Status']
X = X.drop('Status',axis=1) 
X = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, target, test_size=0.2)
# print(X_train.info())
# print(X_test.info())
sm = SMOTE(random_state=2,ratio ='auto')
X_train, y_train = sm.fit_sample(X_train, y_train.ravel())

criteria = ['gini','entropy']
splitter_val = ['best','random']
min_samples_split = [2, 5, 10,15,20,25,30]
min_samples_leaf = [1, 2, 4, 8, 16, 32, 64]
max_features_val = ['auto','sqrt','log2']
presort_val = [True,False]
n_estimators = [int(x) for x in np.linspace(start = 1, stop = 100, num = 10)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]

random_grid = {
               'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap,
               'criterion':criteria,
               'class_weight': ['balanced_subsample','balanced']
               
               }

reg = RandomForestClassifier()
rs_reg = RandomizedSearchCV(estimator = reg,param_distributions=random_grid, n_iter = 20, cv = 2,verbose=2,scoring='roc_auc',n_jobs=3)
rs_reg.fit(X_train,y_train)
print(rs_reg.best_params_)
print(rs_reg.best_score_)
pred = rs_reg.predict(X_test)
print(f1_score(y_test,pred))
# Out:
# Fitting 2 folds for each of 20 candidates, totalling 40 fits
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=90, criterion=gini, class_weight=balanced, bootstrap=True
# [CV] n_estimators=100, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=90, criterion=gini, class_weight=balanced, bootstrap=True
# [CV] n_estimators=78, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=110, criterion=gini, class_weight=balanced_subsample, bootstrap=True
# [CV]  n_estimators=78, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=110, criterion=gini, class_weight=balanced_subsample, bootstrap=True, total=   0.5s
# [CV] n_estimators=78, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=110, criterion=gini, class_weight=balanced_subsample, bootstrap=True
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=90, criterion=gini, class_weight=balanced, bootstrap=True, total=   0.5s
# [CV] n_estimators=12, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=50, criterion=gini, class_weight=balanced, bootstrap=True
# [CV]  n_estimators=12, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=50, criterion=gini, class_weight=balanced, bootstrap=True, total=   0.1s
# [CV] n_estimators=12, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=50, criterion=gini, class_weight=balanced, bootstrap=True
# [CV]  n_estimators=100, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=90, criterion=gini, class_weight=balanced, bootstrap=True, total=   0.6s
# [CV] n_estimators=1, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=90, criterion=gini, class_weight=balanced_subsample, bootstrap=False
# [CV]  n_estimators=1, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=90, criterion=gini, class_weight=balanced_subsample, bootstrap=False, total=   0.0s
# [CV] n_estimators=1, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=90, criterion=gini, class_weight=balanced_subsample, bootstrap=False
# [CV]  n_estimators=1, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=90, criterion=gini, class_weight=balanced_subsample, bootstrap=False, total=   0.0s
# [CV] n_estimators=34, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=70, criterion=entropy, class_weight=balanced, bootstrap=True
# [CV]  n_estimators=12, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=50, criterion=gini, class_weight=balanced, bootstrap=True, total=   0.1s
# [CV] n_estimators=34, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=70, criterion=entropy, class_weight=balanced, bootstrap=True
# [CV]  n_estimators=34, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=70, criterion=entropy, class_weight=balanced, bootstrap=True, total=   0.3s
# [CV] n_estimators=89, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30, criterion=gini, class_weight=balanced_subsample, bootstrap=False
# [CV]  n_estimators=34, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=70, criterion=entropy, class_weight=balanced, bootstrap=True, total=   0.3s
# [CV] n_estimators=89, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30, criterion=gini, class_weight=balanced_subsample, bootstrap=False
# [CV]  n_estimators=78, min_samples_split=10, min_samples_leaf=1, max_features=sqrt, max_depth=110, criterion=gini, class_weight=balanced_subsample, bootstrap=True, total=   0.6s
# [CV] n_estimators=34, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=50, criterion=entropy, class_weight=balanced_subsample, bootstrap=False
# [CV]  n_estimators=34, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=50, criterion=entropy, class_weight=balanced_subsample, bootstrap=False, total=   0.4s
# [CV] n_estimators=34, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=50, criterion=entropy, class_weight=balanced_subsample, bootstrap=False
# [CV]  n_estimators=89, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30, criterion=gini, class_weight=balanced_subsample, bootstrap=False, total=   0.8s
# [CV] n_estimators=34, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=20, criterion=gini, class_weight=balanced, bootstrap=True
# [CV]  n_estimators=89, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30, criterion=gini, class_weight=balanced_subsample, bootstrap=False, total=   0.8s
# [CV] n_estimators=34, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=20, criterion=gini, class_weight=balanced, bootstrap=True
# [CV]  n_estimators=34, min_samples_split=10, min_samples_leaf=2, max_features=auto, max_depth=50, criterion=entropy, class_weight=balanced_subsample, bootstrap=False, total=   0.4s
# [CV] n_estimators=89, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=80, criterion=entropy, class_weight=balanced, bootstrap=False
# [CV]  n_estimators=34, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=20, criterion=gini, class_weight=balanced, bootstrap=True, total=   0.2s
# [CV] n_estimators=89, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=80, criterion=entropy, class_weight=balanced, bootstrap=False
# [CV]  n_estimators=34, min_samples_split=10, min_samples_leaf=1, max_features=auto, max_depth=20, criterion=gini, class_weight=balanced, bootstrap=True, total=   0.2s
# [CV] n_estimators=34, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=None, criterion=entropy, class_weight=balanced, bootstrap=False
# [CV]  n_estimators=34, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=None, criterion=entropy, class_weight=balanced, bootstrap=False, total=   0.4s
# [CV] n_estimators=34, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=None, criterion=entropy, class_weight=balanced, bootstrap=False
# [CV]  n_estimators=34, min_samples_split=2, min_samples_leaf=2, max_features=sqrt, max_depth=None, criterion=entropy, class_weight=balanced, bootstrap=False, total=   0.4s
# [CV] n_estimators=12, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=20, criterion=entropy, class_weight=balanced_subsample, bootstrap=True
# [CV]  n_estimators=12, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=20, criterion=entropy, class_weight=balanced_subsample, bootstrap=True, total=   1.2s
# [CV] n_estimators=12, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=20, criterion=entropy, class_weight=balanced_subsample, bootstrap=True
# [CV]  n_estimators=89, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=80, criterion=entropy, class_weight=balanced, bootstrap=False, total=   1.6s
# [CV] n_estimators=56, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=70, criterion=gini, class_weight=balanced, bootstrap=False
# [CV]  n_estimators=89, min_samples_split=2, min_samples_leaf=1, max_features=sqrt, max_depth=80, criterion=entropy, class_weight=balanced, bootstrap=False, total=   2.1s
# [CV] n_estimators=56, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=70, criterion=gini, class_weight=balanced, bootstrap=False
# [CV]  n_estimators=12, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=20, criterion=entropy, class_weight=balanced_subsample, bootstrap=True, total=   0.1s
# [CV] n_estimators=23, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20, criterion=gini, class_weight=balanced_subsample, bootstrap=True
# [CV]  n_estimators=23, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20, criterion=gini, class_weight=balanced_subsample, bootstrap=True, total=   0.2s
# [CV] n_estimators=23, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20, criterion=gini, class_weight=balanced_subsample, bootstrap=True
# [CV]  n_estimators=56, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=70, criterion=gini, class_weight=balanced, bootstrap=False, total=   0.4s
# [CV] n_estimators=78, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=20, criterion=entropy, class_weight=balanced_subsample, bootstrap=True
# [CV]  n_estimators=56, min_samples_split=10, min_samples_leaf=2, max_features=sqrt, max_depth=70, criterion=gini, class_weight=balanced, bootstrap=False, total=   0.5s
# [CV] n_estimators=78, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=20, criterion=entropy, class_weight=balanced_subsample, bootstrap=True
# [CV]  n_estimators=23, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=20, criterion=gini, class_weight=balanced_subsample, bootstrap=True, total=   0.2s
# [CV] n_estimators=34, min_samples_split=2, min_samples_leaf=4, max_features=sqrt, max_depth=None, criterion=entropy, class_weight=balanced, bootstrap=False
# [CV]  n_estimators=34, min_samples_split=2, min_samples_leaf=4, max_features=sqrt, max_depth=None, criterion=entropy, class_weight=balanced, bootstrap=False, total=   0.3s
# [CV] n_estimators=34, min_samples_split=2, min_samples_leaf=4, max_features=sqrt, max_depth=None, criterion=entropy, class_weight=balanced, bootstrap=False
# [CV]  n_estimators=78, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=20, criterion=entropy, class_weight=balanced_subsample, bootstrap=True, total=   0.6s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=50, criterion=entropy, class_weight=balanced, bootstrap=False
# [CV]  n_estimators=34, min_samples_split=2, min_samples_leaf=4, max_features=sqrt, max_depth=None, criterion=entropy, class_weight=balanced, bootstrap=False, total=   0.3s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=50, criterion=entropy, class_weight=balanced, bootstrap=False
# [CV]  n_estimators=78, min_samples_split=5, min_samples_leaf=4, max_features=sqrt, max_depth=20, criterion=entropy, class_weight=balanced_subsample, bootstrap=True, total=   0.8s
# [CV] n_estimators=56, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30, criterion=gini, class_weight=balanced_subsample, bootstrap=True
# [CV]  n_estimators=56, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30, criterion=gini, class_weight=balanced_subsample, bootstrap=True, total=   0.5s
# [CV] n_estimators=56, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30, criterion=gini, class_weight=balanced_subsample, bootstrap=True
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=50, criterion=entropy, class_weight=balanced, bootstrap=False, total=   0.9s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=None, criterion=gini, class_weight=balanced, bootstrap=True
# [CV]  n_estimators=56, min_samples_split=2, min_samples_leaf=1, max_features=auto, max_depth=30, criterion=gini, class_weight=balanced_subsample, bootstrap=True, total=   0.4s
# [CV] n_estimators=100, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=None, criterion=gini, class_weight=balanced, bootstrap=True
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=50, criterion=entropy, class_weight=balanced, bootstrap=False, total=   1.2s
# [CV] n_estimators=1, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=70, criterion=gini, class_weight=balanced, bootstrap=False
# [CV]  n_estimators=1, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=70, criterion=gini, class_weight=balanced, bootstrap=False, total=   0.0s
# [CV] n_estimators=1, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=70, criterion=gini, class_weight=balanced, bootstrap=False
# [CV]  n_estimators=1, min_samples_split=10, min_samples_leaf=4, max_features=auto, max_depth=70, criterion=gini, class_weight=balanced, bootstrap=False, total=   0.0s
# [CV] n_estimators=12, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=90, criterion=gini, class_weight=balanced_subsample, bootstrap=True
# [CV]  n_estimators=12, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=90, criterion=gini, class_weight=balanced_subsample, bootstrap=True, total=   0.1s
# [CV] n_estimators=12, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=90, criterion=gini, class_weight=balanced_subsample, bootstrap=True
# [Parallel(n_jobs=3)]: Done  35 tasks      | elapsed:    7.1s
# [CV]  n_estimators=12, min_samples_split=5, min_samples_leaf=1, max_features=sqrt, max_depth=90, criterion=gini, class_weight=balanced_subsample, bootstrap=True, total=   0.1s
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=None, criterion=gini, class_weight=balanced, bootstrap=True, total=   0.7s
# [CV]  n_estimators=100, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=None, criterion=gini, class_weight=balanced, bootstrap=True, total=   0.6s
# [Parallel(n_jobs=3)]: Done  40 out of  40 | elapsed:    7.6s finished
# {'n_estimators': 78, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 20, 'criterion': 'entropy', 'class_weight': 'balanced_subsample', 'bootstrap': True}
# 0.7491660453444019
# 0.6161304539444689

# %% [markdown]
# -'n_estimators': 23, 'min_samples_split': 10, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 10, 'criterion': 'gini', 'class_weight': 'balanced_subsample', 'bootstrap': True
# gives 64.5
#
# - {'n_estimators': 78, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 10, 'criterion': 'entropy', 'class_weight': 'balanced', 'bootstrap': True}
# 0.6505808757819481
#
# {'n_estimators': 67, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 10, 'criterion': 'entropy', 'class_weight': 'balanced', 'bootstrap': True}0.6710700132100396 after scaling

# %%
X = train_df.drop(['ID','Start Date','End Date'],axis=1)
    

le = LabelEncoder()
for i in X.select_dtypes('object').columns:
    X[str(i)] = le.fit_transform(X[str(i)])

target = X['Status']
X = X.drop('Status',axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, target, test_size=0.2)
# print(X_train.info())
# print(X_test.info())
X = scaler.fit_transform(X)
sm = SMOTE(random_state=2,ratio ='auto')
X_train, y_train = sm.fit_sample(X_train, y_train.ravel())

clf = xgb.XGBClassifier()

param_grid = {
        'silent': [False],
        'max_depth': [6, 10, 15, 20],
        'learning_rate': [0.001, 0.01, 0.1, 0.2, 0,3],
        'subsample': [0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
        'colsample_bytree': [0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
        'colsample_bylevel': [0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1.0],
        'min_child_weight': [0.5, 1.0, 3.0, 5.0, 7.0, 10.0],
        'gamma': [0, 0.25, 0.5, 1.0],
        'reg_lambda': [0.1, 1.0, 5.0, 10.0, 50.0, 100.0],
        'n_estimators': [100]}


rs_reg = RandomizedSearchCV(clf, param_grid, n_iter=20, verbose=2, cv=4,scoring='roc_auc')
rs_reg.fit(X_train,y_train)
print(rs_reg.best_params_)
# print(rs_reg.best_score_)

reg = xgb.XGBClassifier()
reg.fit(X_train,y_train)
pred = rs_reg.predict(X_test.values)
# pred = rs_reg.predict(X_test)
print(f1_score(y_test,pred))
# Out:
# Fitting 4 folds for each of 20 candidates, totalling 80 fits
# [CV] subsample=0.7, silent=False, reg_lambda=10.0, n_estimators=100, min_child_weight=3.0, max_depth=20, learning_rate=3, gamma=1.0, colsample_bytree=0.8, colsample_bylevel=0.8
# [23:47:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 54 pruned nodes, max_depth=13
# [23:47:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 34 pruned nodes, max_depth=12
# [23:47:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 20 pruned nodes, max_depth=7
# [23:47:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 10 pruned nodes, max_depth=6
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 2 pruned nodes, max_depth=9
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=7
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 2 pruned nodes, max_depth=6
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=6
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=6
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=4
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=4
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=4
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=7
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=4
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=6
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=4
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=6
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=6
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [CV]  subsample=0.7, silent=False, reg_lambda=10.0, n_estimators=100, min_child_weight=3.0, max_depth=20, learning_rate=3, gamma=1.0, colsample_bytree=0.8, colsample_bylevel=0.8, total=   0.2s
# [CV] subsample=0.7, silent=False, reg_lambda=10.0, n_estimators=100, min_child_weight=3.0, max_depth=20, learning_rate=3, gamma=1.0, colsample_bytree=0.8, colsample_bylevel=0.8
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 130 extra nodes, 60 pruned nodes, max_depth=15
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 22 pruned nodes, max_depth=11
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 18 pruned nodes, max_depth=11
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 14 pruned nodes, max_depth=11
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 16 pruned nodes, max_depth=12
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 12 pruned nodes, max_depth=9
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 2 pruned nodes, max_depth=9
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 2 pruned nodes, max_depth=6
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 0 pruned nodes, max_depth=8
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 4 pruned nodes, max_depth=6
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 2 pruned nodes, max_depth=5
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 0 pruned nodes, max_depth=8
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 2 pruned nodes, max_depth=5
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=4
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=4
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [CV]  subsample=0.7, silent=False, reg_lambda=10.0, n_estimators=100, min_child_weight=3.0, max_depth=20, learning_rate=3, gamma=1.0, colsample_bytree=0.8, colsample_bylevel=0.8, total=   0.1s
# [CV] subsample=0.7, silent=False, reg_lambda=10.0, n_estimators=100, min_child_weight=3.0, max_depth=20, learning_rate=3, gamma=1.0, colsample_bytree=0.8, colsample_bylevel=0.8
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 50 pruned nodes, max_depth=12
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 128 extra nodes, 36 pruned nodes, max_depth=12
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 12 pruned nodes, max_depth=7
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 4 pruned nodes, max_depth=13
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 4 pruned nodes, max_depth=7
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 4 pruned nodes, max_depth=10
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 6 pruned nodes, max_depth=5
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [CV]  subsample=0.7, silent=False, reg_lambda=10.0, n_estimators=100, min_child_weight=3.0, max_depth=20, learning_rate=3, gamma=1.0, colsample_bytree=0.8, colsample_bylevel=0.8, total=   0.1s
# [CV] subsample=0.7, silent=False, reg_lambda=10.0, n_estimators=100, min_child_weight=3.0, max_depth=20, learning_rate=3, gamma=1.0, colsample_bytree=0.8, colsample_bylevel=0.8
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 54 pruned nodes, max_depth=15
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 28 pruned nodes, max_depth=8
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 24 pruned nodes, max_depth=11
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 18 pruned nodes, max_depth=8
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 14 pruned nodes, max_depth=10
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 6 pruned nodes, max_depth=7
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=5
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=6
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=6
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 0 pruned nodes, max_depth=1
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [CV]  subsample=0.7, silent=False, reg_lambda=10.0, n_estimators=100, min_child_weight=3.0, max_depth=20, learning_rate=3, gamma=1.0, colsample_bytree=0.8, colsample_bylevel=0.8, total=   0.1s
# [CV] subsample=1.0, silent=False, reg_lambda=1.0, n_estimators=100, min_child_weight=7.0, max_depth=10, learning_rate=0.2, gamma=0.5, colsample_bytree=1.0, colsample_bylevel=1.0
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 248 extra nodes, 28 pruned nodes, max_depth=10
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 268 extra nodes, 28 pruned nodes, max_depth=10
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 284 extra nodes, 10 pruned nodes, max_depth=10
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 252 extra nodes, 24 pruned nodes, max_depth=10
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 250 extra nodes, 22 pruned nodes, max_depth=10
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 214 extra nodes, 32 pruned nodes, max_depth=10
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 230 extra nodes, 18 pruned nodes, max_depth=10
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 236 extra nodes, 20 pruned nodes, max_depth=10
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 24 pruned nodes, max_depth=10
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 174 extra nodes, 34 pruned nodes, max_depth=10
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 140 extra nodes, 14 pruned nodes, max_depth=10
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 182 extra nodes, 16 pruned nodes, max_depth=10
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 28 pruned nodes, max_depth=10
# [23:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 12 pruned nodes, max_depth=10
# ...
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 14 pruned nodes, max_depth=3
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 102 pruned nodes, max_depth=14
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 48 pruned nodes, max_depth=14
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 16 pruned nodes, max_depth=6
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 4 pruned nodes, max_depth=4
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 68 pruned nodes, max_depth=13
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 84 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=6
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 62 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 56 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2 pruned nodes, max_depth=6
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 14 pruned nodes, max_depth=9
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 34 pruned nodes, max_depth=12
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 14 pruned nodes, max_depth=5
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 34 pruned nodes, max_depth=9
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=4
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 24 pruned nodes, max_depth=8
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 34 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 58 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 22 pruned nodes, max_depth=7
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 70 pruned nodes, max_depth=10
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=6
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 64 pruned nodes, max_depth=11
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=7
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 14 pruned nodes, max_depth=4
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 70 pruned nodes, max_depth=10
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 28 pruned nodes, max_depth=6
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=5
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 14 pruned nodes, max_depth=9
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 18 pruned nodes, max_depth=2
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 18 pruned nodes, max_depth=5
# [CV]  subsample=0.6, silent=False, reg_lambda=10.0, n_estimators=100, min_child_weight=3.0, max_depth=15, learning_rate=0.1, gamma=1.0, colsample_bytree=0.5, colsample_bylevel=0.7, total=   0.2s
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 130 pruned nodes, max_depth=11
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 8 pruned nodes, max_depth=9
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 158 extra nodes, 88 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 46 pruned nodes, max_depth=10
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 26 pruned nodes, max_depth=13
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 10 pruned nodes, max_depth=10
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 192 extra nodes, 152 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 8 pruned nodes, max_depth=10
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 80 pruned nodes, max_depth=10
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 62 pruned nodes, max_depth=11
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 74 pruned nodes, max_depth=11
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 52 pruned nodes, max_depth=11
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 18 pruned nodes, max_depth=10
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 12 pruned nodes, max_depth=9
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 4 pruned nodes, max_depth=14
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 18 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 32 pruned nodes, max_depth=8
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 154 extra nodes, 166 pruned nodes, max_depth=13
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 26 pruned nodes, max_depth=9
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 42 pruned nodes, max_depth=10
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 54 pruned nodes, max_depth=13
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 152 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 32 pruned nodes, max_depth=12
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 150 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 78 pruned nodes, max_depth=13
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 28 pruned nodes, max_depth=10
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 34 pruned nodes, max_depth=9
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 122 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 232 extra nodes, 204 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 52 pruned nodes, max_depth=12
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 74 pruned nodes, max_depth=15
# [Parallel(n_jobs=1)]: Done  80 out of  80 | elapsed:   34.5s finished
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 200 extra nodes, 208 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 2 pruned nodes, max_depth=11
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 24 pruned nodes, max_depth=14
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 20 pruned nodes, max_depth=9
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 94 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 210 extra nodes, 162 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 42 pruned nodes, max_depth=8
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 170 extra nodes, 192 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 40 pruned nodes, max_depth=12
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 28 pruned nodes, max_depth=11
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 72 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 38 pruned nodes, max_depth=6
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 168 pruned nodes, max_depth=14
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 98 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 150 extra nodes, 234 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 28 pruned nodes, max_depth=9
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 54 pruned nodes, max_depth=14
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 146 extra nodes, 240 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 12 pruned nodes, max_depth=7
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 52 pruned nodes, max_depth=7
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 142 extra nodes, 120 pruned nodes, max_depth=13
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 46 pruned nodes, max_depth=9
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 24 pruned nodes, max_depth=8
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 186 extra nodes, 254 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 10 pruned nodes, max_depth=11
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 156 extra nodes, 216 pruned nodes, max_depth=14
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 152 extra nodes, 172 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 122 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 184 extra nodes, 256 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 42 pruned nodes, max_depth=11
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 176 pruned nodes, max_depth=14
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 108 pruned nodes, max_depth=14
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 142 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 100 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 136 extra nodes, 90 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 152 pruned nodes, max_depth=14
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 4 pruned nodes, max_depth=8
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 140 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 222 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 62 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 138 extra nodes, 110 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 56 pruned nodes, max_depth=14
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 172 extra nodes, 252 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 34 pruned nodes, max_depth=14
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 114 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 12 pruned nodes, max_depth=6
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 74 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 20 pruned nodes, max_depth=12
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 18 pruned nodes, max_depth=9
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 24 pruned nodes, max_depth=6
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 136 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 152 pruned nodes, max_depth=14
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 60 pruned nodes, max_depth=9
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 126 extra nodes, 194 pruned nodes, max_depth=14
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 52 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 200 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 74 pruned nodes, max_depth=12
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 34 pruned nodes, max_depth=7
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 24 pruned nodes, max_depth=7
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 72 pruned nodes, max_depth=11
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 34 pruned nodes, max_depth=6
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 58 pruned nodes, max_depth=10
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 36 pruned nodes, max_depth=10
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 164 pruned nodes, max_depth=14
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 52 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 34 pruned nodes, max_depth=5
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 204 pruned nodes, max_depth=14
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 102 extra nodes, 110 pruned nodes, max_depth=15
# [23:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 196 pruned nodes, max_depth=14
# {'subsample': 0.8, 'silent': False, 'reg_lambda': 10.0, 'n_estimators': 100, 'min_child_weight': 0.5, 'max_depth': 15, 'learning_rate': 0.1, 'gamma': 1.0, 'colsample_bytree': 0.6, 'colsample_bylevel': 0.5}
# 0.6480706648070664
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %% [markdown]
# 'subsample': 0.7, 'silent': False, 'reg_lambda': 50.0, 'n_estimators': 100, 'min_child_weight': 5.0, 'max_depth': 6, 'learning_rate': 0.2, 'gamma': 1.0, 'colsample_bytree': 0.9, 'colsample_bylevel': 0.4 0.751
# 'subsample': 0.9, 'silent': False, 'reg_lambda': 50.0, 'n_estimators': 100, 'min_child_weight': 7.0, 'max_depth': 15, 'learning_rate': 0.1, 'gamma': 0.25, 'colsample_bytree': 1.0, 'colsample_bylevel': 0.4 0.653153153153153
#
# 'subsample': 0.9, 'silent': False, 'reg_lambda': 50.0, 'n_estimators': 100, 'min_child_weight': 7.0, 'max_depth': 15, 'learning_rate': 0.1, 'gamma': 0.25, 'colsample_bytree': 1.0, 'colsample_bylevel': 0.4}
# 0.655590480466996

# %%
X_train = train_df.drop(['ID','Start Date','End Date'],axis=1)
X_test = test_df.drop(['ID','Start Date','End Date'],axis=1)
ID = test_df['ID']
for i in X_train.select_dtypes('object').columns:
    
    le.fit(X_train[str(i)])
    
    if(str(i)=='Status'):
        print(le.classes_)
    X_train[str(i)] = le.transform(X_train[str(i)])
    if(str(i)!='Status'):
        X_test[str(i)] = le.transform(X_test[str(i)])
y_train = X_train['Status']
X_train = X_train.drop(['Status'],axis=1)

X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

sm = SMOTE(random_state=2,ratio ='auto')
X_train, y_train = sm.fit_sample(X_train, y_train.ravel())

# reg = RandomForestClassifier(n_estimators = 67, min_samples_split= 5, min_samples_leaf=2, max_features='sqrt', max_depth= 10, criterion= 'entropy', class_weight= 'balanced', bootstrap= True)
reg = xgb.XGBClassifier(subsample= 0.9, silent= False, reg_lambda= 50.0, n_estimators= 100,min_child_weight= 7.0, max_depth= 15, learning_rate= 0.1, gamma=0.25, colsample_bytree= 1.0, colsample_bylevel= 0.4)
reg.fit(X_train,y_train)
pred = reg.predict(X_test)
# Out:
# ['Failed' 'Success']
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 2 pruned nodes, max_depth=8
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 2 pruned nodes, max_depth=7
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 6 pruned nodes, max_depth=9
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 14 pruned nodes, max_depth=11
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=7
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 2 pruned nodes, max_depth=8
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 4 pruned nodes, max_depth=9
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 6 pruned nodes, max_depth=8
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 4 pruned nodes, max_depth=11
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 2 pruned nodes, max_depth=12
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 2 pruned nodes, max_depth=7
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 6 pruned nodes, max_depth=10
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 0 pruned nodes, max_depth=12
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 12 pruned nodes, max_depth=13
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 2 pruned nodes, max_depth=4
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=7
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 18 pruned nodes, max_depth=13
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 128 extra nodes, 18 pruned nodes, max_depth=10
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 2 pruned nodes, max_depth=7
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 4 pruned nodes, max_depth=11
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 4 pruned nodes, max_depth=10
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 2 pruned nodes, max_depth=9
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=10
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 0 pruned nodes, max_depth=5
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 2 pruned nodes, max_depth=7
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 0 pruned nodes, max_depth=10
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 2 pruned nodes, max_depth=10
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 46 extra nodes, 4 pruned nodes, max_depth=11
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 6 pruned nodes, max_depth=11
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 6 pruned nodes, max_depth=13
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 0 pruned nodes, max_depth=8
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2 pruned nodes, max_depth=7
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 10 pruned nodes, max_depth=10
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 4 pruned nodes, max_depth=11
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 6 pruned nodes, max_depth=7
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 4 pruned nodes, max_depth=6
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 10 pruned nodes, max_depth=10
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 4 pruned nodes, max_depth=14
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 8 pruned nodes, max_depth=12
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 6 pruned nodes, max_depth=9
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 4 pruned nodes, max_depth=12
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 6 pruned nodes, max_depth=11
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 4 pruned nodes, max_depth=10
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 4 pruned nodes, max_depth=9
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 10 pruned nodes, max_depth=15
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 12 pruned nodes, max_depth=9
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 132 extra nodes, 32 pruned nodes, max_depth=15
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 2 pruned nodes, max_depth=8
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 2 pruned nodes, max_depth=10
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 20 pruned nodes, max_depth=12
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 14 pruned nodes, max_depth=13
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 6 pruned nodes, max_depth=10
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 24 pruned nodes, max_depth=14
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 8 pruned nodes, max_depth=10
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 10 pruned nodes, max_depth=12
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 6 pruned nodes, max_depth=7
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 6 pruned nodes, max_depth=9
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 4 pruned nodes, max_depth=13
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=7
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 14 pruned nodes, max_depth=15
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 18 pruned nodes, max_depth=13
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 28 pruned nodes, max_depth=13
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 6 pruned nodes, max_depth=9
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 6 pruned nodes, max_depth=6
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=9
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 12 pruned nodes, max_depth=15
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 28 pruned nodes, max_depth=15
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 184 extra nodes, 32 pruned nodes, max_depth=15
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 4 pruned nodes, max_depth=9
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 128 extra nodes, 12 pruned nodes, max_depth=10
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 48 extra nodes, 12 pruned nodes, max_depth=10
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 8 pruned nodes, max_depth=10
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 16 pruned nodes, max_depth=10
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 12 pruned nodes, max_depth=11
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 2 pruned nodes, max_depth=9
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 2 pruned nodes, max_depth=15
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 18 pruned nodes, max_depth=15
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 24 pruned nodes, max_depth=15
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 6 pruned nodes, max_depth=10
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 134 extra nodes, 6 pruned nodes, max_depth=14
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 6 pruned nodes, max_depth=13
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 26 pruned nodes, max_depth=15
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 10 pruned nodes, max_depth=9
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 20 pruned nodes, max_depth=15
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 40 extra nodes, 6 pruned nodes, max_depth=12
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 20 pruned nodes, max_depth=14
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 4 pruned nodes, max_depth=12
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 18 pruned nodes, max_depth=9
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 4 pruned nodes, max_depth=9
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 6 pruned nodes, max_depth=10
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 14 pruned nodes, max_depth=14
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 12 pruned nodes, max_depth=13
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 106 extra nodes, 20 pruned nodes, max_depth=15
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 18 pruned nodes, max_depth=11
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 32 pruned nodes, max_depth=14
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 44 extra nodes, 2 pruned nodes, max_depth=10
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 16 pruned nodes, max_depth=10
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 4 pruned nodes, max_depth=11
# [00:02:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 2 pruned nodes, max_depth=9
# /home/lenovo/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
final = {'ID':ID,
        'Status':pred}
final_df = pd.DataFrame(final)
final_df.loc[final_df.Status==1,'Status'] = 'Success'
final_df.loc[final_df.Status==0,'Status'] = 'Failed'
print(final_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8080 entries, 0 to 8079
# Data columns (total 2 columns):
# ID        8080 non-null int64
# Status    8080 non-null object
# dtypes: int64(1), object(1)
# memory usage: 126.3+ KB
# None

# %%
final_df.to_csv('submission.csv',index=False)
